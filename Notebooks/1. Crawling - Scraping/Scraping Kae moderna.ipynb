# %%
# !pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.3.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.2.6)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from snscrape) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.3.4

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
path_csv_file = "/content/gdrive/Shareddrives/Riset Sentimen Vaksin COVID: Yaudahlah/Riset/Crawling/moderna.csv"

# Creating list to append tweet data 
tweets_list = []
for i, tweet in enumerate(sntwitter.TwitterSearchScraper('lang:id until:2022-03-25 since:2021-01-13 (covid OR corona OR korona OR covid19 OR covid-19) (vaksinasi OR vaksin OR vaksinisasi) (moderna)').get_items()):
  tweets_list.append([tweet.id, tweet.url, tweet.content])
  # print(tweet.content)
  # callbacks
  if i == 0:
    pd.DataFrame(tweets_list, columns=["TweetID", "TweetURL", "tweet"]).to_csv(path_csv_file, index=False)
    continue
  if i % 500 == 0:
    df = pd.read_csv(path_csv_file, engine='python')
    df_temp = pd.DataFrame(tweets_list, columns=["TweetID", "TweetURL", "tweet"])
    frames = [df, df_temp]
    combined = pd.concat(frames)
    combined.drop_duplicates(inplace=True)
    combined.to_csv(path_csv_file, index=False)
    tweets_list = []
    print(f"Data saved {i}")

df = pd.read_csv(path_csv_file, engine='python')
df_temp = pd.DataFrame(tweets_list, columns=["TweetID", "TweetURL", "tweet"])
frames = [df, df_temp]
combined = pd.concat(frames)
combined.drop_duplicates(inplace=True)
combined.to_csv(path_csv_file, index=False)
tweets_list = []
print(f"Data saved {len(combined)}")
# Out:
# Data saved 500
# Data saved 1000
# Data saved 1500
# Data saved 2000
# Data saved 2500
# Data saved 3000
# Data saved 3500
# Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_composer_source=true&include_ext_alt_text=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=lang%3Aid+until%3A2022-03-25+since%3A2021-01-13+%28covid+OR+corona+OR+korona+OR+covid19+OR+covid-19%29+%28vaksinasi+OR+vaksin+OR+vaksinisasi%29+%28moderna%29&tweet_search_mode=live&count=100&query_source=spelling_expansion_revert_click&cursor=scroll%3AthGAVUV0VFVBaEwKvZ86qDoCcWgMDR5ZrykOopEnEVtMF1FYCJehgEVVNFUjUBFZIDFQAA&pc=1&spelling_corrections=1&ext=mediaStats%252CcameraMoment: ConnectionError(ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))), retrying
# Data saved 4000
# Data saved 4500
# Data saved 4693
